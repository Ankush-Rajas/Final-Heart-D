# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gradio as gr
import pickle

# %%
x = pd.read_csv('train_heart.csv')
y = pd.read_csv('test_heart.csv')

# %%
x.columns

y.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
y.info()

y.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
plt.subplots(figsize=(15, 10))
sns.heatmap(x.corr(), annot = True)
# Out:
# <Axes: >

# %%
# Histogram of chol

sns.histplot(data=x, x='chol')
plt.title('Histogram of Cholesterol')
plt.show()

# %%
# Bar plot of cp type

sns.countplot(data=x, x='cp', hue='target')
plt.title('Bar Plot of Chest Pain Type')
plt.show()

# %%
#count of males and females having heart disease

sns.countplot(data=x, x='sex', hue='target')
plt.title('Distribution of Heart Disease by Gender')
plt.xlabel('Gender 0 = female, 1 = male')
plt.ylabel('Count')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

# %%
sns.scatterplot(data=x, x='age', y='chol', hue='target')
plt.title('Scatter Plot of Age and Cholesterol with Target')
plt.show()

# %%
sns.histplot(data=x, x='chol', hue='target', multiple='stack')
plt.title("Cholesterol vs Heart Disease")
plt.show()

# %%
sns.histplot(data=x, x='age', bins=20)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(data=x, x='age', hue='target', multiple='stack', bins=20)
plt.title("Age vs Heart Disease")
plt.show()

# %%
#removing target column from data

a_train = x.drop(['target'], axis=1)
b_train = x['target']

a_test = y.drop(['target'], axis=1)
b_test = y['target']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
a_train_s = scaler.fit_transform(a_train)
a_test_s = scaler.transform(a_test)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# scaling
scaler = StandardScaler()
a_train_s = scaler.fit_transform(a_train)
a_test_s = scaler.transform(a_test)

# model
lr_model = LogisticRegression(max_iter=1500)
lr_model.fit(a_train_s, b_train)

# prediction
lr_pred = lr_model.predict(a_test_s)
lr_prob = lr_model.predict_proba(a_test_s)[:, 1]

lr_acc = accuracy_score(b_test, lr_pred)
print("Accuracy:", lr_acc)
# Out:
# Accuracy: 0.8613861386138614

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
plt.bar(["Logistic Regression"], [lr_acc])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("Accuracy - Logistic Regression")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(b_test, lr_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(b_test, lr_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Logistic Regression")
plt.legend()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

precision, recall, _ = precision_recall_curve(b_test, lr_prob)
ap = average_precision_score(b_test, lr_prob)

plt.figure(figsize=(5,5))
plt.plot(recall, precision, label=f"AP = {ap:.2f}")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(lr_prob[b_test==0], bins=20, alpha=0.6, label="No Disease")
plt.hist(lr_prob[b_test==1], bins=20, alpha=0.6, label="Disease")
plt.xlabel("Predicted Probability")
plt.ylabel("Count")
plt.title("Prediction Probability Distribution")
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np

coef_df = pd.DataFrame({
    "Feature": a_train.columns,
    "Coefficient": lr_model.coef_[0]
}).sort_values(by="Coefficient", ascending=False)

plt.figure(figsize=(8,5))
plt.barh(coef_df["Feature"], coef_df["Coefficient"])
plt.gca().invert_yaxis()
plt.title("Feature Importance (Logistic Regression)")
plt.show()

# %%
fp = ((lr_pred == 1) & (b_test == 0)).sum()
fn = ((lr_pred == 0) & (b_test == 1)).sum()

plt.figure(figsize=(4,4))
plt.bar(["False Positive", "False Negative"], [fp, fn])
plt.title("Error Analysis")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)
rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=5,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)
rf_model.fit(a_train, b_train)

rf_model.fit(a_train, b_train)

rf_pred = rf_model.predict(a_test)
rf_prob = rf_model.predict_proba(a_test)[:, 1]

rf_acc = accuracy_score(b_test, rf_pred)
print("Random Forest Accuracy:", rf_acc)
# Out:
# Random Forest Accuracy: 0.9306930693069307

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
plt.bar(["Random Forest"], [rf_acc])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("Accuracy - Random Forest")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(b_test, rf_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Random Forest")
plt.show()

# %%
rf_prob = rf_model.predict_proba(a_test)[:,1]

from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, _ = roc_curve(b_test, rf_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr, lw=2, label=f"AUC = {roc_auc:.2f}")
plt.plot([0,1],[0,1],'--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Random Forest (Regularized)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

scaler = StandardScaler()
a_train_s = scaler.fit_transform(a_train)
a_test_s = scaler.transform(a_test)

svm_model = SVC(kernel='rbf', probability=True, random_state=42)
svm_model.fit(a_train_s, b_train)

svm_pred = svm_model.predict(a_test_s)
svm_prob = svm_model.predict_proba(a_test_s)[:, 1]

svm_acc = accuracy_score(b_test, svm_pred)
print("SVM Accuracy:", svm_acc)
# Out:
# SVM Accuracy: 0.966996699669967

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(b_test, svm_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Purples")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - SVM")
plt.tight_layout()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

scaler = StandardScaler()
a_train_s = scaler.fit_transform(a_train)
a_test_s = scaler.transform(a_test)

knn_model = KNeighborsClassifier(n_neighbors=7)
knn_model.fit(a_train_s, b_train)

knn_pred = knn_model.predict(a_test_s)
knn_prob = knn_model.predict_proba(a_test_s)[:, 1]

knn_acc = accuracy_score(b_test, knn_pred)
print("KNN Accuracy:", knn_acc)
# Out:
# KNN Accuracy: 0.900990099009901

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4,4))
plt.bar(["KNN"], [knn_acc])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("Accuracy - KNN")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(b_test, knn_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Oranges")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - KNN")
plt.tight_layout()
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt_model = DecisionTreeClassifier(
    max_depth=5,        # overfitting control
    random_state=42
)

dt_model.fit(a_train, b_train)

dt_pred = dt_model.predict(a_test)
dt_prob = dt_model.predict_proba(a_test)[:, 1]

dt_acc = accuracy_score(b_test, dt_pred)
print("Decision Tree Accuracy:", dt_acc)
# Out:
# Decision Tree Accuracy: 0.9372937293729373

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

nb_model = GaussianNB()
nb_model.fit(a_train, b_train)

nb_pred = nb_model.predict(a_test)
nb_prob = nb_model.predict_proba(a_test)[:, 1]

nb_acc = accuracy_score(b_test, nb_pred)
print("Naive Bayes Accuracy:", nb_acc)
# Out:
# Naive Bayes Accuracy: 0.834983498349835

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

gb_model = GradientBoostingClassifier(
    n_estimators=150,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

gb_model.fit(a_train, b_train)

gb_pred = gb_model.predict(a_test)
gb_prob = gb_model.predict_proba(a_test)[:, 1]

gb_acc = accuracy_score(b_test, gb_pred)
print("Gradient Boosting Accuracy:", gb_acc)
# Out:
# Gradient Boosting Accuracy: 1.0

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import AdaBoostClassifier

ada_model = AdaBoostClassifier(
    n_estimators=200,
    learning_rate=0.8,
    random_state=42
)

ada_model.fit(a_train, b_train)

ada_pred = ada_model.predict(a_test)
ada_prob = ada_model.predict_proba(a_test)[:, 1]

ada_acc = accuracy_score(b_test, ada_pred)
print("AdaBoost Accuracy:", ada_acc)
# Out:
# AdaBoost Accuracy: 0.9108910891089109

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import accuracy_score

et_model = ExtraTreesClassifier(
    n_estimators=300,
    max_depth=7,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)

et_model.fit(a_train, b_train)

et_pred = et_model.predict(a_test)
et_prob = et_model.predict_proba(a_test)[:, 1]

et_acc = accuracy_score(b_test, et_pred)
print("Extra Trees Accuracy:", et_acc)
# Out:
# Extra Trees Accuracy: 0.9405940594059405

# %%
from sklearn.ensemble import VotingClassifier

hybrid_model = VotingClassifier(
    estimators=[
        ('lr', lr_model),
        ('rf', rf_model),
        ('svm', svm_model),
        ('gb', gb_model),
        ('et', et_model)
    ],
    voting='soft'   # ⭐ IMPORTANT
)

hybrid_model.fit(a_train, b_train)

hyb_pred = hybrid_model.predict(a_test)
hyb_prob = hybrid_model.predict_proba(a_test)[:,1]

# %%
from sklearn.metrics import accuracy_score

hyb_acc = accuracy_score(b_test, hyb_pred)
print("Hybrid Model Accuracy:", hyb_acc)
# Out:
# Hybrid Model Accuracy: 0.9603960396039604

# %%
import matplotlib.pyplot as plt

model_names = [
    "Logistic", "Random Forest", "SVM", "Gradient Boosting", "Extra Trees", "Hybrid"
]
accuracies = [
    lr_acc, rf_acc, svm_acc, gb_acc, et_acc, hyb_acc
]

plt.figure(figsize=(10,5))
plt.bar(model_names, accuracies)
plt.ylim(0.7, 1.0)
plt.ylabel("Accuracy")
plt.title("Accuracy Comparison: Individual Models vs Hybrid")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(b_test, hyb_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Hybrid Model")
plt.tight_layout()
plt.show()

# %%
def parameter_risk_score(p):
    score = 0
    if p["age"] >= 55: score += 1
    if p["trestbps"] >= 140: score += 1
    if p["chol"] >= 240: score += 1
    if p["thalach"] <= 120: score += 1
    if p["exang"] == 1: score += 1
    if p["oldpeak"] > 2: score += 1
    if p["ca"] >= 1: score += 1
    return score

# %%
a_train.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal'],
#       dtype='object')

# %%
patient_medium = {
    "age": 45,
    "sex": 1,
    "cp": 2,
    "trestbps": 135,
    "chol": 230,
    "fbs": 0,
    "restecg": 1,
    "thalach": 145,
    "exang": 0,
    "oldpeak": 1.8,
    "slope": 1,
    "ca": 1,
    "thal": 3
}

# %%
feature_columns = a_train.columns

example_df = pd.DataFrame([patient_medium])
example_df = example_df[feature_columns]   # 🔥 MOST IMPORTANT

# %%
ml_prob = hybrid_model.predict_proba(example_df)[0][1]
param_score = parameter_risk_score(patient_medium)

final_score = (ml_prob * 5) + param_score

if final_score <= 3:
    final_risk = "🟢 LOW RISK"
elif final_score <= 6:
    final_risk = "🟡 MEDIUM RISK"
else:
    final_risk = "🔴 HIGH RISK"

print("Hybrid Probability:", ml_prob)
print("Parameter Score:", param_score)
print("Final Risk Level:", final_risk)
# Out:
# Hybrid Probability: 0.33847289143807097
# Parameter Score: 1
# Final Risk Level: 🟢 LOW RISK

# %%
feature_columns = a_train.columns

# %%
def predict_risk(patient_dict):
    # dataframe with correct order
    df = pd.DataFrame([patient_dict])
    df = df[feature_columns]

    # ML probability
    ml_prob = hybrid_model.predict_proba(df)[0][1]

    # parameter score
    param_score = parameter_risk_score(patient_dict)

    # final score
    final_score = (ml_prob * 5) + param_score

    if final_score <= 3:
        risk = "🟢 LOW RISK"
    elif final_score <= 6:
        risk = "🟡 MEDIUM RISK"
    else:
        risk = "🔴 HIGH RISK"

    return ml_prob, param_score, final_score, risk

# %%
patient_low = {
    "age": 35,
    "sex": 0,
    "cp": 1,
    "trestbps": 118,
    "chol": 185,
    "fbs": 0,
    "restecg": 0,
    "thalach": 172,
    "exang": 0,
    "oldpeak": 0.5,
    "slope": 2,
    "ca": 0,
    "thal": 2
}

ml, ps, fs, risk = predict_risk(patient_low)

print("LOW RISK PATIENT")
print("ML Probability:", ml)
print("Parameter Score:", ps)
print("Final Score:", fs)
print("Final Risk:", risk)
# Out:
# LOW RISK PATIENT
# ML Probability: 0.9376376368788641
# Parameter Score: 0
# Final Score: 4.6881881843943205
# Final Risk: 🟡 MEDIUM RISK

# %%
patient_medium = {
    "age": 55,
    "sex": 1,
    "cp": 2,
    "trestbps": 135,
    "chol": 230,
    "fbs": 0,
    "restecg": 1,
    "thalach": 145,
    "exang": 0,
    "oldpeak": 1.8,
    "slope": 1,
    "ca": 1,
    "thal": 3
}

ml, ps, fs, risk = predict_risk(patient_medium)

print("\nMEDIUM RISK PATIENT")
print("ML Probability:", ml)
print("Parameter Score:", ps)
print("Final Score:", fs)
print("Final Risk:", risk)
# Out:
# MEDIUM RISK PATIENT
# ML Probability: 0.3568911096932809
# Parameter Score: 2
# Final Score: 3.7844555484664046
# Final Risk: 🟡 MEDIUM RISK

# %%
patient_high = {
    "age": 67,
    "sex": 1,
    "cp": 3,
    "trestbps": 160,
    "chol": 280,
    "fbs": 1,
    "restecg": 2,
    "thalach": 110,
    "exang": 1,
    "oldpeak": 3.2,
    "slope": 0,
    "ca": 3,
    "thal": 1
}

ml, ps, fs, risk = predict_risk(patient_high)

print("\nHIGH RISK PATIENT")
print("ML Probability:", ml)
print("Parameter Score:", ps)
print("Final Score:", fs)
print("Final Risk:", risk)
# Out:
# HIGH RISK PATIENT
# ML Probability: 0.1652829394862233
# Parameter Score: 7
# Final Score: 7.826414697431116
# Final Risk: 🔴 HIGH RISK

# %%
import pickle
import pickle

# save hybrid model
with open("hybrid_model.pkl", "wb") as f:
    pickle.dump(hybrid_model, f)

# save scaler (jo tumne train me use kiya)
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# save feature columns (MOST IMPORTANT)
with open("feature_columns.pkl", "wb") as f:
    pickle.dump(a_train.columns.tolist(), f)

print("✅ All files saved successfully")
# Out:
# ✅ All files saved successfully
